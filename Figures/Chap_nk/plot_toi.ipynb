# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits

hdu = fits.open('Neptune_A2_KIDs.fits')
toi1 = (hdu[0].data)[9570:14500]
toi2 = (hdu[1].data)[9570:14500]
toi3 = (hdu[2].data)[9570:14500]
toi4 = (hdu[3].data)[9570:14500]

# %%
fig, ax = plt.subplots()
for toi in [toi1, toi2, toi3]:
    ax.plot(toi)
# Out:
# <img src="data:image/png;base64,..." width="640">
